# %%
require 'daru'
require 'daru_plotting_plotly'
require 'rbplotly'
require 'hg'

class Numeric
  def mili
    self.to_f * 10**(-3)
  end
  
  def micro
    self.to_f * 10**(-6)
  end
end

Daru.plotting_library = :plotly
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    w
# ...

# %% [markdown]
# # 実験10

# %%
Daru::DataFrame.from_csv('data/jikken10.csv', encoding: 'UTF-8').tap do |df|
  df.plot(x: 'Ib', y: 'Ic', layout: {title: 'Ic'}).show
  df.plot(x: 'Ib', y: 'Vc', layout: {title: 'Vc'}).show
  df.plot(x: 'Ib', y: 'Pc', layout: {title: 'トランジスタの消費電力'}).show
  df.plot(x: 'Ib', y: 'Pl', layout: {title: '電球の消費電力'}).show
  df.plot(x: 'Ib', y: 'ef', layout: {title: '変換効率'}).show
end
# Out:
# #<Plotly::Offline::HTML:0x007f84f7a54e60 @id="13a8db63-e9b6-4ae0-9bb9-5a8150c95262", @data=[{:x=>[0.0014, 0.0012, 0.001, 0.0008, 0.0006, 0.0004, 0.0002, 0.0], :y=>[0.138, 0.133, 0.1179, 0.10300000000000001, 0.084, 0.0559, 0.028800000000000003, 0], :type=>:scatter, :mode=>"", :name=>"Ic"}], @layout={:width=>1000, :height=>500, :title=>"Ic"}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>
# #<Plotly::Offline::HTML:0x007f84f7a3cf68 @id="1afa2cca-f1c6-4b86-b9a4-0944043dd89f", @data=[{:x=>[0.0014, 0.0012, 0.001, 0.0008, 0.0006, 0.0004, 0.0002, 0.0], :y=>[0.2, 2.54, 10, 16.9, 24.2, 31.8, 34.3, 35.8], :type=>:scatter, :mode=>"", :name=>"Vc"}], @layout={:width=>1000, :height=>500, :title=>"Vc"}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>
# ...

# %% [markdown]
# # 実験11

# %%
Daru::DataFrame.from_csv('data/jikken11.csv').tap do |df|
  df.plot(x: 'duty_ratio', y: 'Ic', layout: { title: 'コレクタ電流' }).show
  df.plot(x: 'duty_ratio', y: 'Vc', layout: { title: 'コレクタ電圧' }).show
  df.plot(x: 'duty_ratio', y: 'Pl', layout: { title: '負荷の消費電力' }).show
end
nil
# Out:
# #<Plotly::Offline::HTML:0x007f84f7986290 @id="65937a2a-2236-40fd-ba2d-58a8061af054", @data=[{:x=>[12, 22, 33, 50, 66, 76, 78, 88], :y=>[0.032, 0.0465, 0.0619, 0.0828, 0.10200000000000001, 0.1118, 0.114, 0.124], :type=>:scatter, :mode=>"", :name=>"Ic"}], @layout={:width=>1000, :height=>500, :title=>"コレクタ電流"}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>
# #<Plotly::Offline::HTML:0x007f84f75121a0 @id="ac44ea3d-07ea-4980-b6c5-62f8e8b1f431", @data=[{:x=>[12, 22, 33, 50, 66, 76, 78, 88], :y=>[31, 27.7, 23.8, 17.5, 11.9, 8.9, 8, 4.81], :type=>:scatter, :mode=>"", :name=>"Vc"}], @layout={:width=>1000, :height=>500, :title=>"コレクタ電圧"}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>
# ...

# %% [markdown]
# # 実験12

# %%
# 上り
Daru::DataFrame.from_csv('data/jikken_12_up.csv').tap do |df|
  df.vectors = Daru::Index.new(df.vectors.to_a.map(&:to_sym))
  df.add_vector :P, df[:Ia].to_a.zip(df[:Vak].to_a).map { |i, v| i * v }
  df.plot(x: :Ig, y: :Ia, layout: { title: "Ig - Ia", xaxis: { title: 'Ig(A)' }, yaxis: { title: 'Ia(A)' } }).show
  df.plot(x: :Ig, y: :Vak, layout: { title: "Ig - Vak", xaxis: { title: 'Ig(A)' }, yaxis: { title: 'Vak(V)' } }).show
  df.plot(x: :Ig, y: :P, layout: { title: "Ig - P", xaxis: { title: 'Ig(A)' }, yaxis: { title: 'P(W)' } }).show
end
#下り
Daru::DataFrame.from_csv('data/jikken_12_down.csv').tap do |df|
  df.vectors = Daru::Index.new(df.vectors.to_a.map(&:to_sym))
  df.add_vector :P, df[:Ia].to_a.zip(df[:Vak].to_a).map { |i, v| i * v }
  df.plot(x: :Ig, y: :Ia, layout: { title: "Ig - Ia", xaxis: { title: 'Ig(A)' }, yaxis: { title: 'Ia(A)' } }).show
  df.plot(x: :Ig, y: :Vak, layout: { title: "Ig - Vak", xaxis: { title: 'Ig(A)' }, yaxis: { title: 'Vak(V)' } }).show
  df.plot(x: :Ig, y: :P, layout: { title: "Ig - P", xaxis: { title: 'Ig(A)' }, yaxis: { title: 'P(W)' } }).show
end
nil
# Out:
# #<Plotly::Offline::HTML:0x007f84f74304f8 @id="7704f9bf-d223-45a2-a20d-9dd75a74d523", @data=[{:x=>[0.002, 0.004, 0.006, 0.008, 0.009000000000000001, 0.009800000000000001, 0.012, 0.014, 0.016, 0.018000000000000002], :y=>[0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.1365, 0.137, 0.137, 0.137, 0.137], :type=>:scatter, :mode=>"", :name=>"Ia"}], @layout={:width=>1000, :height=>500, :title=>"Ig - Ia", :xaxis=>{:title=>"Ig(A)"}, :yaxis=>{:title=>"Ia(A)"}}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>
# ...

# %% [markdown]
# # 実験13

# %%
Daru::DataFrame.from_csv('data/jikken_13.csv').tap do |df|
  df.vectors = Daru::Index.new(df.vectors.to_a.map(&:to_sym))
  df.plot(x: :Vak, y: :Ia, layout: { title: 'Ia - Vak', xaxis: { title: 'Vak(V)' }, yaxis: { title: 'Ia(A)' } }).show
end
nil
# Out:
# #<Plotly::Offline::HTML:0x007f84f72f3158 @id="77259068-41bb-4eb6-a8ff-a24ede991a4b", @data=[{:x=>[0.77, 0.76, 0.758, 0.754, 0.778, 0.81, 0.8, 0.81, 1.84, 1.75, 1.58, 1.38, 1.19, 0.98, 0.8, 0.6, 0.4, 0.2, 0.1], :y=>[0.0684, 0.06, 0.0489, 0.04020000000000001, 0.0282, 0.0249, 0.024300000000000002, 0.023780000000000003, 0.0009000000000000001, 0.0009000000000000001, 0.0009000000000000001, 0.0005, 0.00045000000000000004, 0.0004, 0.00034, 0.00024, 0.0002, 0.00013000000000000002, 0.0001], :type=>:scatter, :mode=>"", :name=>"Ia"}], @layout={:width=>1000, :height=>500, :title=>"Ia - Vak", :xaxis=>{:title=>"Vak(V)"}, :yaxis=>{:title=>"Ia(A)"}}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>

# %% [markdown]
# ## Vakのターンオン時

# %%
File.open('data/Vak_turn_on.png')
# Out:
# #<File:data/Vak_turn_on.png>

# %% [markdown]
# ## Iaのターンオン時
# ### 全体

# %%
File.open('data/Ia_turn_on_1.png')
# Out:
# #<File:data/Ia_turn_on_1.png>

# %% [markdown]
# ### 拡大

# %%
File.open('data/Ia_turn_on_2.png')
# Out:
# #<File:data/Ia_turn_on_2.png>

# %% [markdown]
# # 実験14

# %%
Daru::DataFrame.from_csv('data/jikken_14.csv').tap do |df|
  df.vectors = Daru::Index.new(df.vectors.to_a.map(&:to_sym))
  half_period = 4.0
  df[:alpha] = df[:length].to_a.map { |it| it / half_period * Math::PI }
  df.plot(x: :alpha, y: :V, layout: { title: 'alpha - V', xaxis: { title: 'alpha' }, yaxis: { title: 'V(V)' } }).show
  df.plot(x: :alpha, y: :I, layout: { title: 'alpha - I', xaxis: { title: 'alpha' }, yaxis: { title: 'I(A)' } }).show
end
nil
# Out:
# #<Plotly::Offline::HTML:0x007f84f7882da8 @id="76ac20b3-4f7b-4809-a036-c571f127cedb", @data=[{:x=>[0.39269908169872414, 0.7853981633974483, 1.1780972450961724, 1.5707963267948966, 1.9634954084936207, 2.356194490192345, 2.748893571891069], :y=>[103.0, 99.0, 90.5, 77.0, 55.0, 32.5, 10.0], :type=>:scatter, :mode=>"", :name=>"V"}], @layout={:width=>1000, :height=>500, :title=>"alpha - V", :xaxis=>{:title=>"alpha"}, :yaxis=>{:title=>"V(V)"}}, @config={:linkText=>"Export to plot.ly", :showLink=>true}, @embedded=true>
# ...

# %% [markdown]
# # 実験15
#
# ## フーリエ級数展開

# %%
[1,2,3,4].zip([1,2,3,4][1..-1])[0...-1]
# Out:
# [[1, 2], [2, 3], [3, 4]]

# %%
degree = 201

coeffs = ['0.25', '0.5', '0.6', '0.75'].map do |name|
  df = Daru::DataFrame.from_csv("data/jikken15/_#{name}.csv")
  period = df.last(1)['second'].first - df.first(1)['second'].first
  omega = 2.0 * Math::PI / period
  rows = df.map_rows.to_a.select { |row| !row['second'].nil? && !row['Volt'].nil? }
  rowsz = rows.zip(rows[1..-1])[0...-1].map { |first, second| [first, second, (second['second'] - first['second'])] }

  a0 = (2.0 / period) * rowsz.map { |first, second, dt| first['Volt'] * dt }.sum

  an = (1..degree).map do |n|
    (2.0 / period) * rowsz.map { |first, second, dt| first['Volt'] * Math.cos(omega * n * first['second']) * dt }.sum
  end

  bn = (1..degree).map do |n|
    (2.0 / period) * rowsz.map { |first, second, dt| first['Volt'] * Math.sin(omega * n * first['second']) * dt }.sum
  end

  f = df['second'].to_a.map do |second|
    a0/2.0 + (1..degree).map do |n|
      an[n-1] * Math.cos(omega * n * second) + bn[n-1] * Math.sin(omega * n * second)
    end.sum
  end

  df.add_vector 'f', f

  df.plot(
    x: 'second',
    y: ['f', 'Volt'],
    layout: {
      xaxis: { title: '秒' },
      yaxis: { title: '電圧' },
      title: "α = #{name}π"
      }).show
  
  [a0, an, bn]
end
nil
# Out:
# #<Plotly::Offline::HTML:0x007f84f75e1068 @id="939d1754-02a4-4ebc-bbb5-d0a47b48c09e", @data=[{:x=>[-0.01048, -0.0104716, -0.0104632, -0.0104548, -0.0104464, -0.010438, -0.0104296, -0.0104212, -0.0104128, -0.0104044, -0.010396, -0.0103876, -0.0103792, -0.0103708, -0.0103624, -0.010354, -0.0103456, -0.0103372, -0.0103288, -0.0103204, -0.010312, -0.0103036, -0.0102952, -0.0102868, -0.0102784, -0.01027, -0.0102616, -0.0102532, -0.0102448, -0.0102364, -0.010228, -0.0102196, -0.0102112, -0.0102028, -0.0101944, -0.010186, -0.0101776, -0.0101692, -0.0101608, -0.0101524, -0.010144, -0.0101356, -0.0101272, -0.0101188, -0.0101104, -0.010102, -0.0100936, -0.0100852, -0.0100768, -0.0100684, -0.01006, -0.0100516, -0.0100432, -0.0100348, -0.0100264, -0.010018, -0.0100096, -0.0100012, -0.0099928, -0.0099844, -0.009976, -0.0099676, -0.0099592, -0.0099508, -0.0099424, -0.009934, -0.0099256, -0.0099172, -0.0099088, -0.0099004, -0.009892, -0.0098836, -0.0098752, -0.0098668, -0.0098584, -0.00985, -0.00984
# ...

# %%
coeffs = ['0.25', '0.5', '0.6', '0.75'].map do |name|
  df = Daru::DataFrame.from_csv("data/jikken15/_#{name}.csv")
  start = df.first(1)['second'].first
  period = df.last(1)['second'].first - df.first(1)['second'].first
  df.map_rows! do |row|
    row['second'] = row['second'] - start
    row
  end
  omega = 2.0 * Math::PI / period
  rows = df.map_rows.to_a.select { |row| !row['second'].nil? && !row['Volt'].nil? }
  rowsz = rows.zip(rows[1..-1])[0...-1].map { |first, second| [first, second, (second['second'] - first['second'])] }

  a0 = (2.0 / period) * rowsz.map { |first, second, dt| first['Volt'] * dt }.sum

  an = (1..degree).map do |n|
    (2.0 / period) * rowsz.map { |first, second, dt| first['Volt'] * Math.cos(omega * n * first['second']) * dt }.sum
  end

  bn = (1..degree).map do |n|
    (2.0 / period) * rowsz.map { |first, second, dt| first['Volt'] * Math.sin(omega * n * first['second']) * dt }.sum
  end

  [a0, an, bn]
end
nil

# %%
e = 141.0
r = 1.0

coeffs.zip([0.25, 0.5, 0.6, 0.75]).map { |arr, alpha| arr + [alpha] }.each do |a0, an, bn, alpha|
  name = alpha
  alpha = alpha * Math::PI
  an_ideal = [e/(2.0 * Math::PI * r) * (Math.cos(2.0 * alpha) - 1.0)]
  an_ideal += (2..degree).map do |n|
    if n.even?
      0
    else
      (2.0*e/r)*(1.0 - n * Math.sin(n * alpha)*Math.sin(alpha) - Math.cos(n * alpha)*Math.cos(alpha))/(Math::PI * (n**2 - 1.0))
    end
  end
  
  bn_ideal = [(e/(2 * Math::PI * r) *(2.0 * Math::PI - 2.0 * alpha + Math.sin(2.0 * alpha)))]
  bn_ideal += (2..degree).map do |n|
    if n.even?
      0
    else
      (2.0*e/r)*(n * Math.cos(n * alpha)*Math.sin(alpha) - Math.sin(n * alpha)*Math.cos(alpha))/(Math::PI * (n**2 - 1.0))
    end
  end

  df = Daru::DataFrame.from_csv("data/jikken15/_#{name}.csv")
  period = df.last(1)['second'].first - df.first(1)['second'].first
  omega = 2.0 * Math::PI / period

  f = df['second'].to_a.map do |second|
    second = second - df.first['second'].first + period/2.0
    (1..degree).map do |n|
      an_ideal[n-1] * Math.cos(omega * n * second) + bn_ideal[n-1] * Math.sin(omega * n * second)
    end.sum
  end

  df.add_vector 'f', f
  df.plot(
    x: 'second',
    y: ['f', 'Volt'],
    layout: {
      xaxis: { title: '位相' },
      yaxis: { title: '電圧' },
      title: "α = #{name}π"
      }).show  
  Plotly::Plot.new(data: [{x: (1..degree).to_a, y: an, mode: 'markers'}, {x: (1..degree).to_a, y: an_ideal.map{ |it| - it }, mode: 'markers' }]).show
  Plotly::Plot.new(data: [{x: (1..degree).to_a, y: bn, mode: 'markers'}, {x: (1..degree).to_a, y: bn_ideal.map{ |it| - it }, mode: 'markers' }]).show
end
nil
# Out:
# #<Plotly::Offline::HTML:0x007f84f7a752a0 @id="a127704f-9eee-4c62-a8e0-e7a7020a465c", @data=[{:x=>[-0.01048, -0.0104716, -0.0104632, -0.0104548, -0.0104464, -0.010438, -0.0104296, -0.0104212, -0.0104128, -0.0104044, -0.010396, -0.0103876, -0.0103792, -0.0103708, -0.0103624, -0.010354, -0.0103456, -0.0103372, -0.0103288, -0.0103204, -0.010312, -0.0103036, -0.0102952, -0.0102868, -0.0102784, -0.01027, -0.0102616, -0.0102532, -0.0102448, -0.0102364, -0.010228, -0.0102196, -0.0102112, -0.0102028, -0.0101944, -0.010186, -0.0101776, -0.0101692, -0.0101608, -0.0101524, -0.010144, -0.0101356, -0.0101272, -0.0101188, -0.0101104, -0.010102, -0.0100936, -0.0100852, -0.0100768, -0.0100684, -0.01006, -0.0100516, -0.0100432, -0.0100348, -0.0100264, -0.010018, -0.0100096, -0.0100012, -0.0099928, -0.0099844, -0.009976, -0.0099676, -0.0099592, -0.0099508, -0.0099424, -0.009934, -0.0099256, -0.0099172, -0.0099088, -0.0099004, -0.009892, -0.0098836, -0.0098752, -0.0098668, -0.0098584, -0.00985, -0.00984
# ...

# %% [markdown]
# ## オシロスコープの画像

# %% [markdown]
# ## $\alpha = 0.25 \pi$

# %%
File.open('data/jikken15/_0.25.png')
# Out:
# #<File:data/jikken15/_0.25.png>

# %% [markdown]
# ## $\alpha = 0.5 \pi$

# %%
File.open('data/jikken15/_0.5.png')
# Out:
# #<File:data/jikken15/_0.5.png>

# %% [markdown]
# ## $\alpha = 0.6 \pi$

# %%
File.open('data/jikken15/_0.6.png')
# Out:
# #<File:data/jikken15/_0.6.png>

# %% [markdown]
# ## $\alpha = 0.75 \pi$

# %%
File.open('data/jikken15/_0.75.png')
# Out:
# #<File:data/jikken15/_0.75.png>
